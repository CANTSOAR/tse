# %%
from orderbook import Orderbook
from basic_bot import bBot1

o1 = bBot1("bot_1_oranges", 50, 55, 100, "oranges")
o2 = bBot1("bot_2_oranges", 45, 50, 100, "oranges")

k1 = bBot1("bot_1_kiwi", 127, 135, 1000, "kiwis")
k2 = bBot1("bot_2_kiwi", 130, 132, 1000, "kiwis")

#figure out how to make certain fields private/uneditable

book = Orderbook([o1, o2, k1, k2])
book.main_loop(100)

book.visualize()
book.animate()
